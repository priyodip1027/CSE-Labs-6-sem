# %% [markdown]
# - # Question 1

# %%
import torch
import numpy as np
from torch.autograd import grad
import matplotlib.pyplot as plt

x = torch.tensor([12.4,14.3,14.5,14.9,16.1,16.9,16.5,15.4,17.0,17.9,18.8,20.3,22.4,19.4,15.5,16.7,17.3,18.4,19.2,17.4,19.5,19.7,21.2])
y = torch.tensor([11.2,12.5,12.7,13.1,14.1,14.8,14.4,13.4,14.9,15.6,16.4,17.7,19.6,16.9,14.0,14.6,15.1,16.1,16.8,15.2,17.0,17.2,18.6])
b = torch.rand([1],requires_grad = True)
w = torch.rand([1],requires_grad = True)
learning_rate = torch.tensor(0.001)
loss_list = []

for epochs in range(100):
    loss = 0.0
    for j in range(len(x)):
        a = w*x[j]
        y_p = a + b
        loss +=(y[j] - y_p)**2
    loss = loss/len(x)
    loss_list.append(loss.item())

    loss.backward()

    with torch.no_grad():
        w -= learning_rate*w.grad
        b -= learning_rate*b.grad

    w.grad = None
    b.grad = None

plt.plot(loss_list)

# %% [markdown]
# - # question 2

# %%
import torch
import numpy as np
from torch.autograd import grad
import matplotlib.pyplot as plt

inp_x = np.array([2,4])
inp_y = np.array([20,40])

x = torch.tensor(inp_x)
y = torch.tensor(inp_y)
b = torch.tensor(1.,requires_grad = True)
w = torch.tensor(1.,requires_grad = True)
learning_rate = torch.tensor(0.001)
loss_list = []
for epochs in range(100):
    loss = 0.0
    for j in range(len(x)):
        a = w*x[j]
        y_p = a + b
        loss += torch.norm(y[j] - y_p)
    loss = loss/len(x)
    loss_list.append(loss.item())
    loss.backward()
    with torch.no_grad():
        w -= learning_rate*w.grad
        b -= learning_rate*b.grad
    w.grad = None
    b.grad = None
    if epochs%10==0:
            print("After {} epochs, w = {},b = {},loss = {}".format(epochs,w,b,loss))

def analytical(x,y,w,b):  
    loss = 0.0
    loss_list = []
    for epochs in range(100):
        for j in range(len(x)):
            y_p = w*x[j] + b
            loss += (y[j] - y_p)
        loss = loss/len(x)
        loss_list.append(loss.item())
        wgrad,bgrad = 0,0
        for i in range(len(x)):
            wgrad += (y_p - y[j])*(x[i])
            bgrad += (y_p - y[j])
        w -= 0.001*wgrad*2/len(x)
        b -= 0.001*bgrad*2/len(x)
        if epochs%10==0:
            print("After {} epochs, w = {},b = {},loss = {}".format(epochs,w,b,loss))

print("Analytical Solution")
analytical(inp_x,inp_y,1,1)
plt.plot(loss_list)
# Out:
# After 0 epochs, w = 1.003000020980835,b = 1.0010000467300415,loss = 26.0
# After 10 epochs, w = 1.0330002307891846,b = 1.0110005140304565,loss = 25.89999771118164
# After 20 epochs, w = 1.0630004405975342,b = 1.0210009813308716,loss = 25.799999237060547
# After 30 epochs, w = 1.0930006504058838,b = 1.0310014486312866,loss = 25.699996948242188
# After 40 epochs, w = 1.1230008602142334,b = 1.0410019159317017,loss = 25.59999656677246
# After 50 epochs, w = 1.153001070022583,b = 1.0510023832321167,loss = 25.499996185302734
# After 60 epochs, w = 1.1830012798309326,b = 1.0610028505325317,loss = 25.399993896484375
# After 70 epochs, w = 1.2130014896392822,b = 1.0710033178329468,loss = 25.299991607666016
# After 80 epochs, w = 1.2430016994476318,b = 1.0810037851333618,loss = 25.199993133544922
# After 90 epochs, w = 1.2730019092559814,b = 1.0910042524337769,loss = 25.09998893737793
# Analytical Solution
# After 0 epochs, w = 1.21,b = 1.07,loss = 26.0
# After 10 epochs, w = 3.0319485874123804,b = 1.677316195804127,loss = 40.63738247248678
# After 20 epochs, w = 4.431941014491706,b = 2.1439803381639013,loss = 30.8189540036006
# After 30 epochs, w = 5.5077006761093354,b = 2.502566892036444,loss = 23.253863011616044
# After 40 epochs, w = 6.334318611449142,b = 2.778106203816379,loss = 17.44079738781509
# After 50 epochs, w = 6.969495068984242,b = 2.989831689661412,loss = 12.974014986046098
# After 60 epochs, w = 7.457567145524643,b = 3.1525223818415453,loss = 9.541721902077061
# After 70 epochs, w = 7.832603639828742,b = 3.2775345466095778,loss = 6.904334459713498
# After 80 epochs, w = 8.120783150234036,b = 3.373594383411342,loss = 4.877755624233229
# After 90 epochs, w = 8.342221414186278,b = 3.4474071380620894,loss = 3.3205245134579684

# %% [markdown]
# - # question 3

# %%
x = torch.tensor([5.0,7.0,12.0,16.0,20.0])
y = torch.tensor([40.0,120.0,180.0,210.0,240.0])
learning_rate = torch.tensor(0.001)
class RegressionModel:
    def __init__(self):
        self.w = torch.rand([1],requires_grad = True)
        self.b = torch.rand([1],requires_grad = True)
    def forward(self,x):
        return self.w*x + self.b
    def update(self):
        self.w -= learning_rate*self.w.grad
        self.b -= learning_rate*self.b.grad
    def reset_grad(self):
        self.w.grad.zero_()
        self.b.grad.zero_()
def criterion(yj,y_p):
    return (yj - y_p)**2
model = RegressionModel()
loss_list = []
for epochs in range(100):
    loss = 0.0
    for j in range(len(x)):
        y_p = model.forward(x)
        loss += torch.norm(y[j] - y_p)
    loss = loss/len(x)
    loss_list.append(loss.item())
    loss.backward()
    with torch.no_grad():
        model.update()
    model.reset_grad()
    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))
plt.plot(loss_list)
# Out:
# After 0 epochs, The parameters are w=tensor([0.8525], requires_grad=True),b=tensor([0.4665], requires_grad=True), and loss =330.359375
# After 10 epochs, The parameters are w=tensor([1.1117], requires_grad=True),b=tensor([0.4888], requires_grad=True), and loss =323.57769775390625
# After 20 epochs, The parameters are w=tensor([1.3670], requires_grad=True),b=tensor([0.5110], requires_grad=True), and loss =316.99298095703125
# After 30 epochs, The parameters are w=tensor([1.6174], requires_grad=True),b=tensor([0.5330], requires_grad=True), and loss =310.6511535644531
# After 40 epochs, The parameters are w=tensor([1.8618], requires_grad=True),b=tensor([0.5548], requires_grad=True), and loss =304.60858154296875
# After 50 epochs, The parameters are w=tensor([2.0985], requires_grad=True),b=tensor([0.5764], requires_grad=True), and loss =298.92852783203125
# After 60 epochs, The parameters are w=tensor([2.3261], requires_grad=True),b=tensor([0.5974], requires_grad=True), and loss =293.6711120605469
# After 70 epochs, The parameters are w=tensor([2.5432], requires_grad=True),b=tensor([0.6179], requires_grad=True), and loss =288.87689208984375
# After 80 epochs, The parameters are w=tensor([2.7494], requires_grad=True),b=tensor([0.6378], requires_grad=True), and loss =284.5522155761719
# After 90 epochs, The parameters are w=tensor([2.9447], requires_grad=True),b=tensor([0.6570], requires_grad=True), and loss =280.6664123535156

# %% [markdown]
# - # Question 4

# %%
import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self,idx):
        return self.X[idx],self.Y[idx]

x = torch.tensor([5.0,7.0,12.0,16.0,20.0])
y = torch.tensor([40.0,120.0,180.0,210.0,240.0])
dataset = MyDataset(x,y)
data_loader = DataLoader(dataset,batch_size=4,shuffle=True)
for data in iter(data_loader):
    print(data) 
learning_rate = torch.tensor(0.001)
class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x):
        return self.w*x + self.b
loss_fn = torch.nn.MSELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.003)
for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        inputs,labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
    loss += loss.item()
    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))
    finalloss = loss/len(data_loader)*4
print(finalloss)
plt.plot(loss_list)
# Out:
# [tensor([ 5., 20., 16.,  7.]), tensor([ 40., 240., 210., 120.])]
# [tensor([12.]), tensor([180.])]
# After 0 epochs, The parameters are w=Parameter containing:
# tensor([14.7434], requires_grad=True),b=Parameter containing:
# tensor([1.3212], requires_grad=True), and loss =365.54638671875
# After 10 epochs, The parameters are w=Parameter containing:
# tensor([13.0214], requires_grad=True),b=Parameter containing:
# tensor([1.6419], requires_grad=True), and loss =2008.8780517578125
# After 20 epochs, The parameters are w=Parameter containing:
# tensor([13.1306], requires_grad=True),b=Parameter containing:
# tensor([1.8974], requires_grad=True), and loss =2131.106689453125
# After 30 epochs, The parameters are w=Parameter containing:
# tensor([13.6500], requires_grad=True),b=Parameter containing:
# tensor([2.5448], requires_grad=True), and loss =1958.5399169921875
# After 40 epochs, The parameters are w=Parameter containing:
# tensor([13.0568], requires_grad=True),b=Parameter containing:
# tensor([2.3789], requires_grad=True), and loss =11.279800415039062
# After 50 epochs, The parameters are w=Parameter containing:
# tensor([14.4392], requires_grad=True),b=Parameter containing:
# tensor([2.5078], requires_grad=True), and loss =1100.2061767578125
# After 60 epochs, The parameters are w=Parameter containing:
# tensor([13.4754], requires_grad=True),b=Parameter containing:
# tensor([2.9847], requires_grad=True), and loss =2100.852294921875
# After 70 epochs, The parameters are w=Parameter containing:
# tensor([13.0386], requires_grad=True),b=Parameter containing:
# tensor([2.9067], requires_grad=True), and loss =15.824947357177734
# After 80 epochs, The parameters are w=Parameter containing:
# tensor([14.3917], requires_grad=True),b=Parameter containing:
# tensor([3.5431], requires_grad=True), and loss =1669.740234375
# After 90 epochs, The parameters are w=Parameter containing:
# tensor([12.0378], requires_grad=True),b=Parameter containing:
# tensor([3.5393], requires_grad=True), and loss =1580.7689208984375
# tensor(3880.4368, grad_fn=<MulBackward0>)

# %% [markdown]
# - # question 5

# %%
import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self,idx):
        return self.X[idx],self.Y[idx]

x = torch.tensor([5.0,7.0,12.0,16.0,20.0])
y = torch.tensor([40.0,120.0,180.0,210.0,240.0])
dataset = MyDataset(x,y)
data_loader = DataLoader(dataset,batch_size=4,shuffle=True)

for data in iter(data_loader):
    print(data)
    
learning_rate = torch.tensor(0.001)
class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x):
        return self.w*x + self.b

loss_fn = torch.nn.MSELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.003)

for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        inputs,labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
    loss += loss.item()

    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))

    finalloss = loss/len(data_loader)*4

print(finalloss)

plt.plot(loss_list)
# Out:
# [tensor([12.,  5., 16.,  7.]), tensor([180.,  40., 210., 120.])]
# [tensor([20.]), tensor([240.])]
# After 0 epochs, The parameters are w=Parameter containing:
# tensor([15.1574], requires_grad=True),b=Parameter containing:
# tensor([1.5655], requires_grad=True), and loss =3917.337646484375
# After 10 epochs, The parameters are w=Parameter containing:
# tensor([9.6350], requires_grad=True),b=Parameter containing:
# tensor([1.5948], requires_grad=True), and loss =2113.491943359375
# After 20 epochs, The parameters are w=Parameter containing:
# tensor([13.6759], requires_grad=True),b=Parameter containing:
# tensor([2.2853], requires_grad=True), and loss =1972.52490234375
# After 30 epochs, The parameters are w=Parameter containing:
# tensor([13.7493], requires_grad=True),b=Parameter containing:
# tensor([2.5822], requires_grad=True), and loss =1829.7520751953125
# After 40 epochs, The parameters are w=Parameter containing:
# tensor([13.7073], requires_grad=True),b=Parameter containing:
# tensor([3.1062], requires_grad=True), and loss =1790.1614990234375
# After 50 epochs, The parameters are w=Parameter containing:
# tensor([12.0806], requires_grad=True),b=Parameter containing:
# tensor([3.1181], requires_grad=True), and loss =1553.3363037109375
# After 60 epochs, The parameters are w=Parameter containing:
# tensor([13.6945], requires_grad=True),b=Parameter containing:
# tensor([3.2580], requires_grad=True), and loss =1779.6297607421875
# After 70 epochs, The parameters are w=Parameter containing:
# tensor([13.1487], requires_grad=True),b=Parameter containing:
# tensor([3.5920], requires_grad=True), and loss =107.3750991821289
# After 80 epochs, The parameters are w=Parameter containing:
# tensor([14.3327], requires_grad=True),b=Parameter containing:
# tensor([4.0552], requires_grad=True), and loss =1848.8778076171875
# After 90 epochs, The parameters are w=Parameter containing:
# tensor([9.3690], requires_grad=True),b=Parameter containing:
# tensor([3.9735], requires_grad=True), and loss =2394.15185546875
# tensor(3441.3164, grad_fn=<MulBackward0>)

# %%
'''What is Python? Executive Summary
Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python su'''

print("hello")
# Out:
# hello
